# %% [markdown]
# # Testing the utilities functions
# For simplification, they are already tested via modified, pipeline-ready formats.

# %%
from pathlib import Path
import os
import numpy as np

from ddf.apply_transforms.prepare_data_for_prediction import prepare_moving_images_for_inference
from ddf.apply_transforms.probability_maps import create_structure_probability_maps

# %%
# find project root (folder that contains .git)
ROOT = Path.cwd()
while not (ROOT / ".git").exists():
    ROOT = ROOT.parent

# set working directory to root
os.chdir(ROOT)

print("Now working in:", Path.cwd())
# Out:
# Now working in: C:\Users\Wiktoria\Documents\GitHub\robust-radiotherapy-planning

# %% [markdown]
# ## prepare_data_for_prediction.py

# %%
prepare_moving_images_for_inference(
    data_file=Path("src/data_full/data_dict.json"),
    data_dir=Path("src/data_full/CT"),
    save_dir=Path("RESULTS/DEFORMATIONS/APPLY_TRANSFORMS/moving_images"),
)
# Out:
# Processing patient 01
# Finished patient 01
# Processing patient 10
# Finished patient 10
# Processing patient 15
# Finished patient 15
# Processing patient 16
# Finished patient 16
# Processing patient 17
# Finished patient 17
# Processing patient 23
# Finished patient 23
# Processing patient 26
# Finished patient 26
# Processing patient 40
# Finished patient 40
# Processing patient 41
# Finished patient 41
# Processing patient 46
# Finished patient 46
# Processing patient 51
# Finished patient 51
# Processing patient 52
# Finished patient 52
# Processing patient 59
# Finished patient 59
# Processing patient 72
# Finished patient 72
# Processing patient 73
# Finished patient 73
#
# All patients processed successfully.

# %% [markdown]
# ## probability_maps.py

# %%
create_structure_probability_maps(
    data_file=Path("src/data_full/data_dict.json"),
    save_dir=Path("RESULTS/DEFORMATIONS/APPLY_TRANSFORMS/STRUCTURES_Ts"),
    aff=np.eye(4),
)

# %% [markdown]
# It is impossible to test, as currently the data is lacking. To be investigated later.

# %% [markdown]
# ## dice.py
